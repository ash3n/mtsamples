# %%
# !pip install transformers[torch] evaluate

# %%
import os
import shutil
if os.path.exists('output_dir'):
  shutil.rmtree('output_dir')

import pandas as pd
import numpy as np
import torch

# %%
from data import get_mtsamples_dataset

ds_train, ds_val, ds_test = get_mtsamples_dataset('mtsamples.csv')
# Out:
# Dataset size: 3429

# %%
from model import build_classifier, evaluate_classifier

model, trainer = build_classifier(ds_train, ds_val)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.bias', 'pre_classifier.weight', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='860' max='860' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [860/860 13:07, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.816600</td>
#       <td>2.741914</td>
#       <td>0.302326</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.708600</td>
#       <td>2.713617</td>
#       <td>0.302326</td>
#     </tr>
#     <tr>
#       <td>150</td>
# ...

# %%
metrics = evaluate_classifier(model, ds_test)

print()
print('Accuracy:', metrics['accuracy'])
print('Macro Average F1:', metrics['macro'])
print('Weighted Average F1:', metrics['weighted'])
pd.DataFrame(metrics['f1_metrics'])
# Out:
# 100%|██████████| 342/342 [00:07<00:00, 47.04it/s]
# Accuracy: 0.30409356725146197
# Macro Average F1: 0.17692034501770307
# Weighted Average F1: 0.2793052701891212
#     Precision    Recall        F1  Support
# 0    0.250000  0.263158  0.256410       19
# 1    0.000000  0.000000  0.000000        4
# 2    0.276190  0.292929  0.284314       99
# 3    0.325000  0.590909  0.419355       22
# 4    0.315789  0.666667  0.428571        9
# 5    0.333333  0.200000  0.250000       10
# 6    0.611111  0.647059  0.628571       17
# 7    0.171429  0.171429  0.171429       35
# 8    0.300000  0.400000  0.342857       30
# 9    0.000000  0.000000  0.000000        2
# 10   0.500000  0.111111  0.181818        9
# 11   0.000000  0.000000  0.000000        2
# 12   0.250000  0.230769  0.240000       13
# 13   1.000000  0.400000  0.571429        5
# 14   0.000000  0.000000  0.000000        3
# 15   0.000000  0.000000  0.000000        2
# 16   0.000000  0.000000  0.000000        2
# ...
